# %% [markdown]
# <a href="https://colab.research.google.com/github/AnjulaMehto/AI_UCC304/blob/main/Creation_of_Dataset1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Q.1 Create Dataset
import pandas as pd
mydataset = {
     'cars':["Tata", "BMW", "Ford"],
     'passing' : [3,7,2]
 }
df = pd.DataFrame(mydataset)
print(df)
print(df.loc[0])
# Out:
#    cars  passing
# 0  Tata        3
# 1   BMW        7
# 2  Ford        2
# cars       Tata
# passing       3
# Name: 0, dtype: object

# %%
import pandas as pd
data ={
    'calories':[450, 450, 560],
    'duration': [20, 40, 50]
}
df=pd.DataFrame(data)
print(df)
print(df.loc[1])
# Out:
#    calories  duration
# 0       450        20
# 1       450        40
# 2       560        50
# calories    450
# duration     40
# Name: 1, dtype: int64

# %%
#Pandas series
import pandas as pd
a =[1,7,2]
data1=pd.Series(a)
print(data1)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
#Label in Pandas
import pandas as pd
a=[1,7,2]
myvar = pd.Series(a, index=["X", "Y", "Z"])
print(myvar)
# Out:
# X    1
# Y    7
# Z    2
# dtype: int64

# %%
#Read CSV file
import pandas as pd
df=pd.read_csv('concrete_data.csv')
df.drop(df.columns[1], axis=1, inplace=True)
df.drop(1, axis=0)
df.head()
#print(df.to_string())
# Out:
#    Cement  Fly Ash  Water  Superplasticizer  Coarse Aggregate  Fine Aggregate  \
# 0   540.0      0.0  162.0               2.5            1040.0           676.0
# 1   540.0      0.0  162.0               2.5            1055.0           676.0
# 2   332.5      0.0  228.0               0.0             932.0           594.0
# 3   332.5      0.0  228.0               0.0             932.0           594.0
# 4   198.6      0.0  192.0               0.0             978.4           825.5
#
#    Age  Strength
# 0   28     79.99
# 1   28     61.89
# 2  270     40.27
# 3  365     41.05
# 4  360     44.30
